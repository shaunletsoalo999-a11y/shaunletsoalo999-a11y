# %% [markdown]
# <a href="https://colab.research.google.com/github/shaunletsoalo999-a11y/shaunletsoalo999-a11y/blob/main/crocodile_species.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/archive.zip')
display(df)
# Out:
#      Observation ID                             Common Name  \
# 0                 1                     Morelet's Crocodile
# 1                 2                      American Crocodile
# 2                 3                       Orinoco Crocodile
# 3                 4                     Morelet's Crocodile
# 4                 5      Mugger Crocodile (Marsh Crocodile)
# ..              ...                                     ...
# 995             996                  West African Crocodile
# 996             997             Hall's New Guinea Crocodile
# 997             998  West African Slender-snouted Crocodile
# 998             999  West African Slender-snouted Crocodile
# 999            1000             Hall's New Guinea Crocodile
#
#             Scientific Name        Family       Genus  Observed Length (m)  \
# 0      Crocodylus moreletii  Crocodylidae  Crocodylus                 1.90
# 1         Crocodylus acutus  Crocodylidae  Crocodylus                 4.09
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot of Observed Length vs. Observed Weight
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Observed Length (m)', y='Observed Weight (kg)', alpha=0.6)
plt.title('Observed Length vs. Observed Weight')
plt.xlabel('Observed Length (m)')
plt.ylabel('Observed Weight (kg)')
plt.grid(True)
plt.show()

# Bar plot of Conservation Status distribution
plt.figure(figsize=(10, 6))
sns.countplot(data=df, y='Conservation Status', order=df['Conservation Status'].value_counts().index, palette='viridis')
plt.title('Distribution of Conservation Status')
plt.xlabel('Count')
plt.ylabel('Conservation Status')
plt.show()
# Out:
# /tmp/ipython-input-4176583750.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='Conservation Status', order=df['Conservation Status'].value_counts().index, palette='viridis')

# %%
# Calculate the average observed length for each age class
average_length_by_age_class = df.groupby('Age Class')['Observed Length (m)'].mean()
print("Average Observed Length by Age Class:")
display(average_length_by_age_class)

# Analyze trends over time within each age class (optional: can add more sophisticated trend analysis)
print("\nTrend of Observed Length over time within each Age Class (first 5 and last 5 observations):")
for age_class, data in df_sorted.groupby('Age Class'):
    print(f"\nAge Class: {age_class}")
    display(data[['index', 'Observed Length (m)']].head())
    display(data[['index', 'Observed Length (m)']].tail())
# Out:
# Average Observed Length by Age Class:
# Age Class
# Adult        2.835784
# Hatchling    0.414082
# Juvenile     1.546701
# Subadult     2.625547
# Name: Observed Length (m), dtype: float64
# Trend of Observed Length over time within each Age Class (first 5 and last 5 observations):
#
# Age Class: Adult
#    index  Observed Length (m)
# 0      0                 1.90
# 1      1                 4.09
# 3      3                 2.42
# 4      4                 3.75
# 5      5                 2.64
#      index  Observed Length (m)
# 992    992                 2.26
# 994    994                 3.40
# 995    995                 2.55
# 997    997                 2.34
# 998    998                 2.82
# Age Class: Hatchling
#      index  Observed Length (m)
# 25      25                 0.34
# 42      42                 0.29
# 56      56                 0.43
# 155    155                 0.16
# 169    169                 0.36
#      index  Observed Length (m)
# 887    887                 0.27
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['index']
  ys = series['Observed Length (m)']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_12.sort_values('index', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('Age Class')):
  _plot_series(series, series_name, i)
  fig.legend(title='Age Class', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('Observed Length (m)')

# %%
from matplotlib import pyplot as plt
_df_16['Observation ID'].plot(kind='line', figsize=(8, 4), title='Observation ID')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_7.groupby('Conservation Status').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
